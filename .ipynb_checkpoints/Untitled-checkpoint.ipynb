# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv("IRIS.csv")
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.shape
# Out:
# (150, 5)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
data.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [raw]
# sayısal değişkenler arasında korelasiyon olup olmadığını göstermek için korelasyon matrisini çizelim

# %%
data.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [raw]
# korelasyon katsayılarını daha iyi anlayabilmek için ısı haritasını çizelim

# %%
sns.heatmap(data.corr())
# Out:
# <AxesSubplot:>

# %% [raw]
# data çerçevemizin hedef değişkeninin "species" benzersiz değerlerini görüntüleyelim

# %%
print(data["species"].unique())
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']

# %% [raw]
# data çerçevesinde sepal_width ve sepal_length değerlerini sürekli görünüyor bu iki sürekli veriyi görseleştirelim

# %%
sns.scatterplot(x="sepal_width",y="sepal_length",data=data,color="red")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='sepal_length'>

# %% [raw]
# aynı iki veriyi daha farkli bir açıdan frankası ile incelemek için joinplot() kulanarak görseleştirelim

# %%
sns.jointplot(x="sepal_width",y="sepal_length", data=data, color="#7FFF00")

# %%
data["species"].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: species, dtype: int64

# %% [raw]
# verilerin dengeli dağılıp dağılmadığı ile ilgili bilgi için value_counts() metodu kulandık

# %%
sns.violinplot(y="sepal_width",data=data,color="blue")
# Out:
# <AxesSubplot:ylabel='sepal_width'>

# %% [raw]
# sepal_width değerinin dağılımını keman grafiği ile inceledik

# %%
sns.distplot(data["sepal_width"],color="red")
# Out:
# <AxesSubplot:xlabel='sepal_width', ylabel='Density'>

# %% [raw]
# displot grafiğini çizdik

# %%
sns.countplot(x="species",data=data)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %% [raw]
# veri dağılımına baktık dengeli bir veri dağılımına sahip

# %%
sns.jointplot(x="sepal_length",y="sepal_width",kind="kde",data=data,color="#006400")

# %% [raw]
# yoğunluk odaklı bir görel denedik kind="kde" kulanarak

# %%
sns.scatterplot(x="petal_length",y="petal_width",data=data,hue="species")
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.lmplot(x="petal_length",y="petal_width",data=data)

# %% [raw]
# petal=length ve petal_width arasında ilişkiye bakıyoruz

# %%
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %%
data.groupby(["species"]).mean()
# Out:
#                  sepal_length  sepal_width  petal_length  petal_width
# species
# Iris-setosa             5.006        3.418         1.464        0.244
# Iris-versicolor         5.936        2.770         4.260        1.326
# Iris-virginica          6.588        2.974         5.552        2.026

# %% [raw]
# değişkenlerin ortalama değrelrini aldık

# %%
data.groupby(["species"])["petal_length"].std()
# Out:
# species
# Iris-setosa        0.173511
# Iris-versicolor    0.469911
# Iris-virginica     0.551895
# Name: petal_length, dtype: float64

# %% [raw]
# petal değişkenimizin standart sapmasını gösterdik
